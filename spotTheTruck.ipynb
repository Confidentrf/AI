# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# Load the image using OpenCV
image_color = cv2.imread('Find_Truck_color.jpg')

# Check if the image is loaded successfully
if image_color is None:
    print("Error: Image not found or failed to load.")
else:
    # Convert the image from BGR to RGB for displaying correctly in matplotlib
    image_rgb = cv2.cvtColor(image_color, cv2.COLOR_BGR2RGB)

    # Display the image using matplotlib
    plt.imshow(image_rgb)
    plt.title('Find Truck Template Matching')
    plt.axis('off')  # Hide axis
    plt.show()

# %%
height, width = image_color.shape[:2]

# %%
height
# Out:
# 628

# %%
width
# Out:
# 1194

# %%
plt.imshow(image_color)

# %%
# Draw a box around the object (if found)
top_left = (620, 150)
bottom_right = (810, 350)
cv2.rectangle(image_color, top_left, bottom_right, (0,0,255), 5)
# Out:
# array([[[204, 185, 170],
#         [206, 187, 172],
#         [209, 190, 175],
#         ...,
#         [214, 210, 209],
#         [214, 210, 209],
#         [214, 210, 209]],
#
#        [[215, 196, 181],
#         [216, 198, 181],
#         [218, 199, 184],
#         ...,
#         [214, 210, 209],
#         [215, 211, 210],
#         [215, 211, 210]],
#
#        [[219, 199, 182],
#         [219, 199, 181],
#         [218, 200, 183],
#         ...,
#         [215, 211, 210],
#         [214, 212, 211],
#         [214, 212, 211]],
#
#        ...,
#
#        [[ 34,  31,  26],
#         [ 34,  31,  26],
#         [ 34,  31,  26],
#         ...,
#         [  1,   1,   1],
#         [  1,   1,   1],
#         [  1,   1,   1]],
#
#        [[ 33,  30,  25],
#         [ 33,  30,  25],
#         [ 33,  30,  25],
#         ...,
#         [  1,   1,   1],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[ 32,  29,  24],
#         [ 32,  29,  24],
#         [ 31,  28,  23],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]]], dtype=uint8)

# %%
# Check if the image is loaded successfully
if image_color is None:
    print("Error: Image not found or failed to load.")
else:
    # Display the image using cv2_imshow
    cv2_imshow(image_color)
    print("Truck Found!")
# Out:
# <PIL.Image.Image image mode=RGB size=1194x628>
# Truck Found!
