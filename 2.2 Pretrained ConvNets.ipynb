# %%
# Enable TensorFlow 2.0
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.15.0'

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from keras.applications.imagenet_utils import decode_predictions

# %%
#Load the VGG16 model
vgg_model = tf.keras.applications.vgg16.VGG16(weights='imagenet')

# %%
vgg16_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3dae85dfe7bd> in <cell line: 1>()
# ----> 1 vgg16_model.summary()
#
# NameError: name 'vgg16_model' is not defined

# %%
len(vgg16_model.layers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-07e2bda3df53> in <cell line: 1>()
# ----> 1 len(vgg16_model.layers)
#
# NameError: name 'vgg16_model' is not defined
